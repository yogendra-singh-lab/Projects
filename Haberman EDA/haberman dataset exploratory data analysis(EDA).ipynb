# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# We will perform exploratory data analysis on a kaggle data set named 'haberman'

# %% [markdown]
# # About the data set

# %% [markdown]
# The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.

# %%
# importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing the data set as data frame
df = pd.read_csv('E:\\applied Ai\\data sets\\16.2. haberman.csv')

# %% [markdown]
# # knowing the data set

# %% [markdown]
# # objective:-

# %% [markdown]
# 1. data points and features of data set
# 2.data types of features
# 3.feature names of data set
# 4. data points of each category of a feature

# %%
df.shape
# Out:
# (306, 4)

# %%
df.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
df.head()
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %% [markdown]
# The first 5 datapoints are printed here.
#
# First column shows the age of patients
#
# Second column shows the year each patient had undergone the surgery during 1958 and 1970
#
# Third column shows the number of numbers of tumors they found
#
# Fourth column shows the survival status of the patients.
#
# If the value is 1 - The patient survived 5 years or more
#
# If the value is 2 - The patient survived less than 5 years

# %%
df['status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %% [markdown]
# # observation

# %% [markdown]
# 'haberman' data set has 306 data point and 4 features ,every feature are of 'int' datatype and feature 'status' has two categories (1 and 2) contains 224 and 81 data points respectively.

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# # OBJECTIVE:-

# %% [markdown]
# Performing bivariate analysis to understand which binomial features are impotant towards classification using 'SCATTER PLOT','PAIR PLOTS'

# %%
# pair-plots
sns.set_style("whitegrid");
sns.pairplot(df,hue = 'status',size = 3);
plt.show()
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # observation:-

# %% [markdown]
# 1. pair plot is showing that the feature "nodes" is an important feature to classify as lumph nodes whose values less than 5 have survived more than 5 years i.e their survival status  is 1.
# 2. combination of age and lymph node another key factor to classify the survival status.

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# # objective:-

# %% [markdown]
# performing a univairate analysis to find out which feature indiviadualy is highly impactful for classification by performing pdf,cdf and box plot.

# %%
sns.FacetGrid(df, hue="status", size=5) \
   .map(sns.distplot, "age") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df, hue="status", size=5) \
   .map(sns.distplot, "nodes") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df, hue="status", size=5) \
   .map(sns.distplot, "year") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # PDF,CDF,BOX PLOT

# %%
df_1 = df.loc[df["status"] == 1 ]
counts, bin_edges = np.histogram(df_1['nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)

#compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)



plt.show();
# Out:
# [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]

# %%
df_2 = df.loc[df["status"] == 2]
counts, bin_edges = np.histogram(df_2['nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)

#compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)



plt.show();
# Out:
# [0.56790123 0.14814815 0.13580247 0.04938272 0.07407407 0.
#  0.01234568 0.         0.         0.01234568]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %%
df_1 = df.loc[df["status"] == 1 ]
counts, bin_edges = np.histogram(df_1['nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)

#compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

df_2 = df.loc[df["status"] == 2]
counts, bin_edges = np.histogram(df_2['nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)

#compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)



plt.show();
# Out:
# [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]
# [0.56790123 0.14814815 0.13580247 0.04938272 0.07407407 0.
#  0.01234568 0.         0.         0.01234568]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %% [markdown]
# # observation

# %% [markdown]
# 1. those who got no lymph nodes or nodes=<0 have surival status of 1 which they lived for 5 or more than 5 years
# 2. those who got nodes <4.2 also have status value  = 1
# 3.those who have 4.2<nodes<10.4 have 77% status  = 1 and 42% status  = 2
# 4.those who have age less than 40 have survival status  = 1 with 7% error

# %% [markdown]
# # MEAN, MEDIAN, IQR(inter quartile range) ,MAD(median absolute deviation)

# %%
df.describe()
# Out:
#               age        year       nodes      status
# count  306.000000  306.000000  306.000000  306.000000
# mean    52.457516   62.852941    4.026144    1.264706
# std     10.803452    3.249405    7.189654    0.441899
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.750000   65.750000    4.000000    2.000000
# max     83.000000   69.000000   52.000000    2.000000

# %% [markdown]
# # observation:-

# %% [markdown]
# 1.mean age of patients is 52.5
# 2.mean value for nodes is 4.02
# 3.youngest and oldest patient ages are 30 and 83 respectively
# 4.maximum node value  = 52
# 5.75% have node value less than or equal to 4

# %%
# calculating 90th percentile and mad
print("\n90th Percentiles: for age")
print(np.percentile(df_1["age"],90))
print("\n90th Percentiles: for nodes whose status = 1")
print(np.percentile(df_1["nodes"],90))
print("\n90th Percentiles: for nodes whose status = 2")
print(np.percentile(df_2["nodes"],90))
print("\n95th Percentiles: for nodes whose status = 1")
print(np.percentile(df_1["nodes"],95))
print("\n95th Percentiles: for nodes whose status = 1")
print(np.percentile(df_1["nodes"],95))
# Out:
# 90th Percentiles: for age
# 67.0
#
# 90th Percentiles: for nodes whose status = 1
# 8.0
#
# 90th Percentiles: for nodes whose status = 2
# 20.0
#
# 95th Percentiles: for nodes whose status = 1
# 14.0
#
# 95th Percentiles: for nodes whose status = 1
# 14.0

# %%
#mad
from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(df_1['nodes']))
print(robust.mad(df_2["nodes"]))
# Out:
# Median Absolute Deviation
# 0.0
# 5.930408874022408

# %% [markdown]
# # BOX PLOT AND VOILIN PLOT

# %%
#boxplot
sns.boxplot(x = 'status',y = 'nodes',data = df)
plt.show()

# %%
#voilin plot
sns.violinplot(x="status", y="nodes", data=df, size=8)
plt.show()

# %% [markdown]
# # observation:-

# %% [markdown]
# 1.where nodes is less than has high density pdf for status =1
